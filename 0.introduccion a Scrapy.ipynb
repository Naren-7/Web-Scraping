# %% [markdown]
# # Introducción

# %% [markdown]
# El web scraping en una técnica en programación que permite extraer información de las páginas web de forma automática a partir de su estructura HTML, XML, entre otras.

# %% [markdown]
# Haremos uso del framework Scrapy

# %% [markdown]
# ## Ventajas

# %% [markdown]
# - No depende de una API.

# %% [markdown]
# - No existen limitaciones de tiempo para extraer información

# %% [markdown]
# ## Procesos

# %% [markdown]
# 1. Obtener URL

# %% [markdown]
# undefined. Request, petición a la página.

# %% [markdown]
# undefined. Response, respuesta de la página en formato HTML O XML.

# %% [markdown]
# undefined. Populate Ítems, Obtener la información a partir de una etiqueta de los formatos ya mencionados.

# %% [markdown]
# ## Tipos de Scraping

# %% [markdown]
# ### Para una sola página web

# %% [markdown]
# - scrapy.spiders.Spider

# %% [markdown]
# ### Para varias páginas web

# %% [markdown]
# - scrapy.spiders.CrawlSpider

# %% [markdown]
# - Crawling Vertical

# %% [markdown]
# - Crawling Horizontal

# %% [markdown]
# Esta última Clase nos permitirá navega en varias direcciones en distintas páginas webs, para recorrer los ítems.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7abc8528-fab7-4652-af5b-2676e9bd9b00' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
